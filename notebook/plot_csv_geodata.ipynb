# %%
import geopandas as gpd
from geopandas import GeoDataFrame
import geodatasets
from matplotlib import pyplot as plt

# %%
# plot the data
file = "../data/out/era5_data_2024_01_02_monthly_area_celsius.geojson"
gdf = gpd.read_file(file)

# %%
# this is a simple map that goes with geopandas
fig, ax = plt.subplots(figsize=(15,10))
gdf.plot(ax=ax, column="t2m", legend=True, markersize=0.001)
fig.tight_layout()
fig.show()
fig.savefig("january.pdf")
# Out:
# /tmp/ipykernel_285997/66533361.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
